# %%
import numpy as np
import matplotlib.pyplot as plt

def make_sine_wave(x, A, w):
    return A * np.sin(w * x)

x = np.linspace(0, 2 * np.pi, 1000)

amplitudes = [0.5, 1, 1.5, 2, 2.5]
frequencies = [1, 2, 3, 4, 5]

plt.figure(figsize=(10, 6))

for A, w in zip(amplitudes, frequencies):
    y = make_sine_wave(x, A, w)
    plt.plot(x, y, label=f"A={A}, w={w}")

plt.title("Sine Waves with Differing Amplitudes and Frequencies")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("stars.csv")

print("Shape of the data (rows, columns):", df.shape)
print("\nColumn names and data types:\n", df.dtypes)

average_mass = df["Mass (M☉)"].mean()
print("\nAverage Mass (M☉):", average_mass)

average_temperature = df["Temperature (K)"].mean()
print("Average Temperature (K):", average_temperature)

largest_radius_star = df.loc[df["Radius (R☉)"].idxmax()]
print("\nStar with the Largest Radius:")
print(largest_radius_star)

m_type_stars = df[df["Spectral_Type"].str.startswith("M")]
print("\nNumber of M-type Stars:", len(m_type_stars))

closest_stars = df.sort_values("Distance (ly)").head(3)
print("\n3 Closest Stars:")
print(closest_stars)
# Out:
# Shape of the data (rows, columns): (10, 6)
#
# Column names and data types:
#  Name                object
# Distance (ly)      float64
# Mass (M☉)          float64
# Radius (R☉)        float64
# Temperature (K)      int64
# Spectral_Type       object
# dtype: object
#
# Average Mass (M☉): 0.579
# Average Temperature (K): 6370.6
#
# Star with the Largest Radius:
# Name               Sirius A
# Distance (ly)           8.6
# Mass (M☉)              2.02
# Radius (R☉)            1.71
# Temperature (K)        9940
# Spectral_Type           A1V
# Name: 5, dtype: object
#
# Number of M-type Stars: 6
#
# 3 Closest Stars:
#                Name  Distance (ly)  Mass (M☉)  Radius (R☉)  Temperature (K)  \
# 0  Proxima Centauri           4.24       0.12         0.14             3042
# 1  Alpha Centauri A           4.37       1.10         1.22             5790
# 2  Alpha Centauri B           4.37       0.91         0.86             5260
#
#   Spectral_Type
# 0        M5.5Ve
# 1           G2V
# ...

# %%
import seaborn as sns  
import matplotlib.pyplot as plt  


penguins = sns.load_dataset("penguins")

fig, axes = plt.subplots(1, 2, figsize=(14, 6)) 

sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_depth_mm", hue="species", ax=axes[0])

axes[0].set_title("Scatter Plot of Flipper Length vs Bill Depth")
axes[0].set_xlabel("Flipper Length (mm)")
axes[0].set_ylabel("Bill Depth (mm)")

sns.histplot(data=penguins, x="body_mass_g", kde=True, ax=axes[1], color='orange')

axes[1].set_title("Histogram of Penguin Body Mass")
axes[1].set_xlabel("Body Mass (g)")
axes[1].set_ylabel("Frequency")

plt.tight_layout()  
plt.show()
